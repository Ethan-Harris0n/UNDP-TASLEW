# %%
# !cd '/Users/ethanharrison/Documents/UNDP/Twitter Package Dev'
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ethan.harrison/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import UNDP_CREW_Twitter
import pandas as pd
from UNDP_CREW_Twitter.sentiment import SentimentModel
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
df = pd.read_csv('/Users/ethanharrison/Documents/UNDP/Twitter_basic/MM.csv')
df['id'] = df.id.astype(int)
df.set_index('id', inplace=True)

# %%
df['text_clean'] = df.text_clean.astype(str)
clean = df.get_text_df('text_clean')

# %%
### Test ngrams ###
clean.dropna(inplace=True)
z = clean.get_ngrams(n = 100, ngram=3)
z.value_counts()
# Out:
# [[1 1 1 ... 3 1 1]]
# <ipython-input-10-05d3db7315b5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean.dropna(inplace=True)
# /Users/ethanharrison/Documents/UNDP/Twitter Package Dev/UNDP_CREW_Twitter/core.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[varname] = df.iloc[:,0].apply(lambda x:(add_ngrams(x,pop_bigrams))) # inefficient - need to convert to list comprehension
# democracy youths from        105
# military dictatorship and     70
# end of military               68
# the end of                    68
# dictatorship and against      68
#                             ...
# to the monks                  37
# any respect to                37
# even tortured the             37
# pro democracy youths          23
# the pro democracy              2
# Name: ngrams, Length: 64, dtype: int64

# %%
clean.get_keywords_tfidf(4, wordtype=False)
# Out:
#                     id                                         text_clean  \
# 0  1446358346584498176  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
# 1  1446358334483795969   MyanmarCovidSOS Oct8Coup WhatsHappeningInMyanmar
# 2  1446358323608104973  Anti coup strike in a village from Sagaing Reg...
# 3  1446358320399347715  Anti coup strike in a village from Sagaing s S...
# 4  1446358315835944963  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
#
#                                          corpus_text  \
# 0  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
# 1   MyanmarCovidSOS Oct8Coup WhatsHappeningInMyanmar
# 2  Anti coup strike in a village from Sagaing Reg...
# 3  Anti coup strike in a village from Sagaing s S...
# 4  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
#
#                                             keywords
# 0  {'standfordemocracy': 0.525, 'asean': 0.519, '...
# 1  {'myanmarcovidsos': 0.929, 'whatshappeninginmy...
# 2  {'usual': 0.497, 'shwebo': 0.416, 'sagaing': 0...
# 3  {'usual': 0.532, 'shwebo': 0.445, 'sagaing': 0...
# 4  {'standfordemocracy': 0.525, 'asean': 0.519, '...
#                                     keywords
# id
# 1446358346584498176        standfordemocracy
# 1446358346584498176                    asean
# 1446358346584498176  whatshappeninginmyanmar
# 1446358346584498176                 oct8coup
# 1446358334483795969          myanmarcovidsos
# ...                                      ...
# 1446351776555225091                  erupted
# 1446351776551096320                 mandalay
# 1446351776551096320                meikhtila
# 1446351776551096320                    paper
# 1446351776551096320                     coup
#
# [3922 rows x 1 columns]

# %%
temp.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a2cfbb94685c> in <module>
# ----> 1 temp.value_counts()
#
# NameError: name 'temp' is not defined

# %%
clean['text_clean']
# Out:
# id
# 1446358346584498176    ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
# 1446358334483795969     MyanmarCovidSOS Oct8Coup WhatsHappeningInMyanmar
# 1446358323608104973    Anti coup strike in a village from Sagaing Reg...
# 1446358320399347715    Anti coup strike in a village from Sagaing s S...
# 1446358315835944963    ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
#                                              ...
# 1446351790442749954    SAC troops stationed in Chaungkhwa village Kal...
# 1446351786705555456    Night protest against military dictatorship by...
# 1446351782838427648    Around 1 000 refugees from Thayetchaung Tsp Ta...
# 1446351776555225091    Yesterday the clashes between SAC soldiers and...
# 1446351776551096320    Pro democracy youths from Mandalay s Meikhtila...
# Name: text_clean, Length: 1000, dtype: object

# %%
from UNDP_CREW_Twitter.core import *
clean
extract_tfidf_keywords(clean, 20)

clean
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-5559feb57da1> in <module>
#       1 from UNDP_CREW_Twitter.core import *
#       2 clean
# ----> 3 extract_tfidf_keywords(clean, 20)
#       4
#       5 clean
#
# ~/Documents/UNDP/Twitter Package Dev/UNDP_CREW_Twitter/core.py in extract_tfidf_keywords(data, nwords, varname, wordtype)
#     200     keywords_df = keywords_df[['keywords']]
#     201     if wordtype==True:
# --> 202         keywords_df['POS'] = nltk.pos_tag(keywords_df.keywords)
#     203         keywords_df['keywords'], keywords_df['POS'] = zip(*keywords_df['POS'])
#     204         return keywords_df
#
# /usr/local/Caskroom/miniforge/base/envs/packagedev-tweetcrew/lib/python3.8/site-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     159     """
#     160     tagger = _get_tagger(lang)
# --> 161     return _pos_tag(tokens, tagset, tagger, lang)
#     162
#     163
#
# /usr/local/Caskroom/miniforge/base/envs/packagedev-tweetcrew/lib/python3.8/site-packages/nltk/tag/__init__.py in _pos_tag(tokens, tagset, tagger, lang)
#     116         )
#     117     else:
# --> 118         tagged_tokens = tagger.tag(tokens)
#     119         if tagset:  # Maps to the specified tagset.
#     120             if lang == "eng":
#
# /usr/local/Caskroom/miniforge/base/envs/packagedev-tweetcrew/lib/python3.8/site-packages/nltk/tag/perceptron.py in tag(self, tokens, return_conf, use_tagdict)
#     179         output = []
#     180
# --> 181         context = self.START + [self.normalize(w) for w in tokens] + self.END
#     182         for i, word in enumerate(tokens):
#     183             tag, conf = (
#
# /usr/local/Caskroom/miniforge/base/envs/packagedev-tweetcrew/lib/python3.8/site-packages/nltk/tag/perceptron.py in <listcomp>(.0)
#     179         output = []
#     180
# --> 181         context = self.START + [self.normalize(w) for w in tokens] + self.END
#     182         for i, word in enumerate(tokens):
#     183             tag, conf = (
#
# /usr/local/Caskroom/miniforge/base/envs/packagedev-tweetcrew/lib/python3.8/site-packages/nltk/tag/perceptron.py in normalize(self, word)
#     274         :rtype: str
#     275         """
# --> 276         if "-" in word and word[0] != "-":
#     277             return "!HYPHEN"
#     278         elif word.isdigit() and len(word) == 4:
#
# TypeError: argument of type 'float' is not iterable

# %%
sentdf = SentimentModel(clean, text_col='text_clean', model='vadar')
sentdf.fit_model()
# sentdf.test()
# Out:
# /Users/ethanharrison/Documents/UNDP/Twitter Package Dev/UNDP_CREW_Twitter/sentiment.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['compound'] = [analyzer.polarity_scores(x)['compound'] for x in (self.df[self.text_col])]
# /Users/ethanharrison/Documents/UNDP/Twitter Package Dev/UNDP_CREW_Twitter/sentiment.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['neg'] = [analyzer.polarity_scores(x)['neg'] for x in (self.df[self.text_col])]
# /Users/ethanharrison/Documents/UNDP/Twitter Package Dev/UNDP_CREW_Twitter/sentiment.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['neu'] = [analyzer.polarity_scores(x)['neu'] for x in (self.df[self.text_col])]
# /Users/ethanharrison/Documents/UNDP/Twitter Package Dev/UNDP_CREW_Twitter/sentiment.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['pos'] = [analyzer.polarity_scores(x)['pos'] for x in (self.df[self.text_col])]
#                                                             text_clean  \
# id
# 1446358346584498176  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
# 1446358334483795969   MyanmarCovidSOS Oct8Coup WhatsHappeningInMyanmar
# 1446358323608104973  Anti coup strike in a village from Sagaing Reg...
# 1446358320399347715  Anti coup strike in a village from Sagaing s S...
# 1446358315835944963  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
# ...                                                                ...
# 1446351790442749954  SAC troops stationed in Chaungkhwa village Kal...
# 1446351786705555456  Night protest against military dictatorship by...
# 1446351782838427648  Around 1 000 refugees from Thayetchaung Tsp Ta...
# 1446351776555225091  Yesterday the clashes between SAC soldiers and...
# 1446351776551096320  Pro democracy youths from Mandalay s Meikhtila...
#
#                      compound    neg    neu    pos
# id
# 1446358346584498176    0.0000  0.000  1.000  0.000
# 1446358334483795969    0.0000  0.000  1.000  0.000
# 1446358323608104973   -0.4215  0.241  0.759  0.000
# 1446358320399347715   -0.4215  0.241  0.759  0.000
# 1446358315835944963    0.0000  0.000  1.000  0.000
# ...                       ...    ...    ...    ...
# 1446351790442749954    0.3254  0.000  0.891  0.109
# 1446351786705555456   -0.2500  0.118  0.882  0.000
# 1446351782838427648   -0.3182  0.142  0.776  0.082
# 1446351776555225091    0.0000  0.000  1.000  0.000
# 1446351776551096320   -0.4215  0.241  0.759  0.000
#
# [1000 rows x 5 columns]

# %%
analyzer = SentimentIntensityAnalyzer()
clean['compound'] = [analyzer.polarity_scores(x)['compound'] for x in clean['text_clean']]
clean
# Out:
# <ipython-input-4-aa58fb747cb2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean['compound'] = [analyzer.polarity_scores(x)['compound'] for x in clean['text_clean']]
#                                                             text_clean  \
# id
# 1446358346584498176  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
# 1446358334483795969   MyanmarCovidSOS Oct8Coup WhatsHappeningInMyanmar
# 1446358323608104973  Anti coup strike in a village from Sagaing Reg...
# 1446358320399347715  Anti coup strike in a village from Sagaing s S...
# 1446358315835944963  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
# ...                                                                ...
# 1446351790442749954  SAC troops stationed in Chaungkhwa village Kal...
# 1446351786705555456  Night protest against military dictatorship by...
# 1446351782838427648  Around 1 000 refugees from Thayetchaung Tsp Ta...
# 1446351776555225091  Yesterday the clashes between SAC soldiers and...
# 1446351776551096320  Pro democracy youths from Mandalay s Meikhtila...
#
#                      compound
# id
# 1446358346584498176    0.0000
# 1446358334483795969    0.0000
# 1446358323608104973   -0.4215
# 1446358320399347715   -0.4215
# 1446358315835944963    0.0000
# ...                       ...
# 1446351790442749954    0.3254
# 1446351786705555456   -0.2500
# 1446351782838427648   -0.3182
# 1446351776555225091    0.0000
# 1446351776551096320   -0.4215
#
# [1000 rows x 2 columns]

# %%
# Out:
#                     id                                         text_clean  \
# 0  1446358346584498176  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
# 1  1446358334483795969   MyanmarCovidSOS Oct8Coup WhatsHappeningInMyanmar
# 2  1446358323608104973  Anti coup strike in a village from Sagaing Reg...
# 3  1446358320399347715  Anti coup strike in a village from Sagaing s S...
# 4  1446358315835944963  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
#
#   ngrams                                        corpus_text  \
# 0     []  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
# 1     []   MyanmarCovidSOS Oct8Coup WhatsHappeningInMyanmar
# 2     []  Anti coup strike in a village from Sagaing Reg...
# 3     []  Anti coup strike in a village from Sagaing s S...
# 4     []  ASEAN StandForDemocracy Oct8Coup WhatsHappenin...
#
#                                             keywords
# 0  {'standfordemocracy': 0.525, 'asean': 0.519, '...
# 1  {'myanmarcovidsos': 0.929, 'whatshappeninginmy...
# 2  {'usual': 0.497, 'shwebo': 0.416, 'sagaing': 0...
# 3  {'usual': 0.532, 'shwebo': 0.445, 'sagaing': 0...
# 4  {'standfordemocracy': 0.525, 'asean': 0.519, '...
